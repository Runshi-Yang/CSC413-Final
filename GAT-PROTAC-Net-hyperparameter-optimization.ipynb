# %% [markdown]
# ## CSC413 - research project
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DeepPROTACs
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1_2em3v0TLxpcrRipRJlWxC6PKaqk5biD/DeepPROTACs

# %%
! pip install torch
! pip install torch_geometric
! pip install rdkit
! pip install optuna
! pip install tqdm
! pip install torch-scatter -f https://pytorch-geometric.com/whl/cu111/torch-2.0.0.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (2.0.0+cu118)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch) (3.11.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (16.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.9/dist-packages (2.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (5.9.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (2.27.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (1.22.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch_geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rdkit in /usr/local/lib/python3.9/dist-packages (2022.9.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from rdkit) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rdkit) (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.9/dist-packages (3.1.1)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.10.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (2.0.9)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/cu111/torch-2.0.0.html
# Requirement already satisfied: torch-scatter in /usr/local/lib/python3.9/dist-packages (2.1.1)

# %%
print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
# Out:
# PyTorch version: 2.0.0+cu118
# CUDA version: 11.8

# %%
import sys
import numpy as np
import torch
import os
import pickle
import logging
import torch_scatter
from pathlib import  Path
from torch import nn
from torch.utils.data import DataLoader, WeightedRandomSampler
from torch.utils.tensorboard import SummaryWriter
from protacloader2 import PROTACSet, collater
from model_Evianne2 import GraphConv, SmilesNet, ProtacModel
from train_and_test2 import train
from prepare_data2 import GraphData

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BATCH_SIZE = 149
EPOCH = 897
TRAIN_RATE = 0.8966428653293104
LEARNING_RATE = 0.0005452702173718947
WEIGHT_DECAY = 0.00014473607817389365
TRAIN_NAME = "optuna_large_data_model_Evianne2"
root = "large_dataset/data"
for handler in logging.root.handlers[:]:
      logging.root.removeHandler(handler)
logging.basicConfig(filename="/content/drive/MyDrive/DeepPROTACs/log/"+TRAIN_NAME+".log", filemode="a", level=logging.DEBUG, force=True)
logging.getLogger('RootLogger').setLevel(logging.DEBUG)

# %%
Path('/content/drive/MyDrive/DeepPROTACs/log').mkdir(exist_ok=True)
Path('/content/drive/MyDrive/DeepPROTACs/model').mkdir(exist_ok=True)

# %%
import optuna
from tqdm.notebook import tqdm


def objective(trial):

    batch_size = trial.suggest_int("batch_size", 1, 512)
    epoch = trial.suggest_int("epoch", 100, 1000)
    train_rate = trial.suggest_float("train_rate", 0.7, 0.9)
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
    weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)

    ligase_pocket = GraphData("ligase_pocket", root)
    target_pocket = GraphData("target_pocket", root)
    PROTAC = GraphData("PROTAC", root)
    with open('small_dataset/name.pkl', 'rb') as f:
        name_list = pickle.load(f)
    label = torch.load(os.path.join(target_pocket.processed_dir, "label.pt"))

    protac_set = PROTACSet(
        name_list,
        ligase_pocket,
        target_pocket,
        PROTAC,
        label,
    )

    data_size = len(protac_set)
    train_size = int(data_size * train_rate)
    test_size = data_size - train_size
    train_dataset = torch.utils.data.Subset(protac_set, range(train_size))
    test_dataset = torch.utils.data.Subset(protac_set, range(train_size, data_size))
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collater, drop_last=False)
    testloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, collate_fn=collater, drop_last=False)

    ligase_pocket_model = GraphConv(num_embeddings=5)
    target_pocket_model = GraphConv(num_embeddings=5)
    PROTAC_model = GraphConv(num_embeddings=10)
    model = ProtacModel(
        ligase_pocket_model,
        target_pocket_model,
        PROTAC_model,
    )
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model, train_loss, val_loss = train(
        model,
        train_loader=trainloader,
        valid_loader=testloader,
        device=device,
        batch_size=batch_size,
        epoch=epoch,
        lr=learning_rate,
        weight_decay=weight_decay
    )

    return val_loss[-1]


study = optuna.create_study(direction="minimize")

with tqdm(total=100, desc="Optimizing", ncols=80) as progress_bar:
    def callback(study, trial):
        progress_bar.update(1)

    study.optimize(objective, n_trials=100, callbacks=[callback])

print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2023-04-19 01:11:08,602] A new study created in memory with name: no-name-94fe3385-378c-440f-9b24-70b2e83c6d2d
# Optimizing:   0%|                                       | 0/100 [00:00<?, ?it/s]
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:11:39,009] Trial 0 finished with value: 0.6526243388652802 and parameters: {'batch_size': 228, 'epoch': 543, 'train_rate': 0.7549937076773736, 'learning_rate': 1.8590177409263038e-05, 'weight_decay': 4.339180614535149e-06}. Best is trial 0 with value: 0.6526243388652802.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:12:06,932] Trial 1 finished with value: 0.6092149913311005 and parameters: {'batch_size': 149, 'epoch': 497, 'train_rate': 0.7641621880642507, 'learning_rate': 2.0425762035117108e-05, 'weight_decay': 0.005057733689640255}. Best is trial 1 with value: 0.6092149913311005.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:12:23,570] Trial 2 finished with value: 0.6009242683649063 and parameters: {'batch_size': 51, 'epoch': 112, 'train_rate': 0.8076927294521777, 'learning_rate': 0.0071834743202403035, 'weight_decay': 0.0005458424901971646}. Best is trial 2 with value: 0.6009242683649063.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:12:39,329] Trial 3 finished with value: 0.4758007675409317 and parameters: {'batch_size': 238, 'epoch': 230, 'train_rate': 0.7185588079164759, 'learning_rate': 0.005630880731474028, 'weight_decay': 2.3253574208709124e-06}. Best is trial 3 with value: 0.4758007675409317.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:13:06,396] Trial 4 finished with value: 0.5343290468056997 and parameters: {'batch_size': 81, 'epoch': 553, 'train_rate': 0.8060917000253822, 'learning_rate': 0.0002673990203985341, 'weight_decay': 0.002576828749240232}. Best is trial 3 with value: 0.4758007675409317.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:13:36,156] Trial 5 finished with value: 0.4938497543334961 and parameters: {'batch_size': 342, 'epoch': 279, 'train_rate': 0.7893990569257243, 'learning_rate': 0.00785883109043362, 'weight_decay': 3.1471874869112015e-06}. Best is trial 3 with value: 0.4758007675409317.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:15:01,130] Trial 6 finished with value: 0.4606934040784836 and parameters: {'batch_size': 25, 'epoch': 436, 'train_rate': 0.8080251226097558, 'learning_rate': 0.002613993835450913, 'weight_decay': 7.853493276503526e-06}. Best is trial 6 with value: 0.4606934040784836.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:15:37,990] Trial 7 finished with value: 0.424415647983551 and parameters: {'batch_size': 291, 'epoch': 671, 'train_rate': 0.7604493552360615, 'learning_rate': 0.001008722543344258, 'weight_decay': 1.094567996019364e-05}. Best is trial 7 with value: 0.424415647983551.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:16:19,311] Trial 8 finished with value: 0.48782673478126526 and parameters: {'batch_size': 416, 'epoch': 463, 'train_rate': 0.8548489307467775, 'learning_rate': 0.0008248425224507023, 'weight_decay': 1.2138697394738522e-05}. Best is trial 7 with value: 0.424415647983551.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:16:45,088] Trial 9 finished with value: 0.6172422766685486 and parameters: {'batch_size': 457, 'epoch': 751, 'train_rate': 0.7820017266482938, 'learning_rate': 2.2312487991080788e-05, 'weight_decay': 0.0012946478707023114}. Best is trial 7 with value: 0.424415647983551.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:18:12,242] Trial 10 finished with value: 0.46363750100135803 and parameters: {'batch_size': 340, 'epoch': 967, 'train_rate': 0.7005461876067289, 'learning_rate': 0.00023358507044122983, 'weight_decay': 5.786290781395899e-05}. Best is trial 7 with value: 0.424415647983551.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:20:11,978] Trial 11 finished with value: 0.4845689272179323 and parameters: {'batch_size': 9, 'epoch': 736, 'train_rate': 0.8438141134181166, 'learning_rate': 0.0012299155089160719, 'weight_decay': 1.6168377103625482e-05}. Best is trial 7 with value: 0.424415647983551.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:20:49,634] Trial 12 finished with value: 0.4027578830718994 and parameters: {'batch_size': 170, 'epoch': 733, 'train_rate': 0.8893689062609574, 'learning_rate': 0.0019714741314047547, 'weight_decay': 5.340874140992645e-05}. Best is trial 12 with value: 0.4027578830718994.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:21:57,441] Trial 13 finished with value: 0.316682368516922 and parameters: {'batch_size': 154, 'epoch': 767, 'train_rate': 0.8862774522836427, 'learning_rate': 0.0008843766850462107, 'weight_decay': 9.058441942853009e-05}. Best is trial 13 with value: 0.316682368516922.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:23:29,468] Trial 14 finished with value: 0.3106837868690491 and parameters: {'batch_size': 149, 'epoch': 897, 'train_rate': 0.8966428653293104, 'learning_rate': 0.0005452702173718947, 'weight_decay': 0.00014473607817389365}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:24:32,170] Trial 15 finished with value: 0.39466553926467896 and parameters: {'batch_size': 140, 'epoch': 966, 'train_rate': 0.8969982364947277, 'learning_rate': 0.0005186845984513472, 'weight_decay': 0.00025484539054383226}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:25:19,903] Trial 16 finished with value: 0.42579859495162964 and parameters: {'batch_size': 105, 'epoch': 861, 'train_rate': 0.8735201637137837, 'learning_rate': 0.0001478314325472135, 'weight_decay': 0.00015624491256727234}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:26:08,898] Trial 17 finished with value: 0.5208050012588501 and parameters: {'batch_size': 181, 'epoch': 856, 'train_rate': 0.8702232877717402, 'learning_rate': 0.00010102833242245601, 'weight_decay': 1.1478153824424196e-06}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:26:54,768] Trial 18 finished with value: 0.4826497435569763 and parameters: {'batch_size': 210, 'epoch': 831, 'train_rate': 0.8966476407709457, 'learning_rate': 0.0005367715547436973, 'weight_decay': 0.00037922289278499044}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:27:24,304] Trial 19 finished with value: 0.3959699869155884 and parameters: {'batch_size': 293, 'epoch': 645, 'train_rate': 0.8409158399569571, 'learning_rate': 0.0027828009272167433, 'weight_decay': 7.197552879432543e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:28:44,706] Trial 20 finished with value: 0.4783437252044678 and parameters: {'batch_size': 93, 'epoch': 985, 'train_rate': 0.8288745507088449, 'learning_rate': 0.00046565439938809277, 'weight_decay': 0.0008049899376063061}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:29:58,847] Trial 21 finished with value: 0.40640494227409363 and parameters: {'batch_size': 129, 'epoch': 914, 'train_rate': 0.8981983182710728, 'learning_rate': 0.000641660683257533, 'weight_decay': 0.0002257275837587606}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:30:43,545] Trial 22 finished with value: 0.522929310798645 and parameters: {'batch_size': 187, 'epoch': 997, 'train_rate': 0.875709138631096, 'learning_rate': 0.00045194149448007226, 'weight_decay': 0.0001438581735764943}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:31:18,584] Trial 23 finished with value: 0.36103418469429016 and parameters: {'batch_size': 126, 'epoch': 807, 'train_rate': 0.8994673353604702, 'learning_rate': 0.0014534408069836698, 'weight_decay': 3.1383382707244165e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:32:33,724] Trial 24 finished with value: 0.41254304349422455 and parameters: {'batch_size': 74, 'epoch': 803, 'train_rate': 0.8787862385617714, 'learning_rate': 0.001539636432748108, 'weight_decay': 2.7353819391449962e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:33:09,147] Trial 25 finished with value: 0.43037283420562744 and parameters: {'batch_size': 278, 'epoch': 643, 'train_rate': 0.8639890785746611, 'learning_rate': 0.0034970487949777225, 'weight_decay': 2.8528609469007518e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:33:38,641] Trial 26 finished with value: 0.4250083565711975 and parameters: {'batch_size': 125, 'epoch': 789, 'train_rate': 0.8845930648456682, 'learning_rate': 0.0010761124780348035, 'weight_decay': 9.594151815042752e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:34:00,725] Trial 27 finished with value: 0.449337363243103 and parameters: {'batch_size': 206, 'epoch': 902, 'train_rate': 0.8575346334122714, 'learning_rate': 0.0018707316015849074, 'weight_decay': 3.454770487186251e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:34:15,628] Trial 28 finished with value: 0.4743908643722534 and parameters: {'batch_size': 52, 'epoch': 896, 'train_rate': 0.8868124681803713, 'learning_rate': 0.0036548370693061227, 'weight_decay': 0.00012377737284728296}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:35:01,052] Trial 29 finished with value: 0.4165949523448944 and parameters: {'batch_size': 256, 'epoch': 723, 'train_rate': 0.8980748656728339, 'learning_rate': 0.0009051311095433444, 'weight_decay': 5.947439148484547e-06}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:35:45,074] Trial 30 finished with value: 0.42663663625717163 and parameters: {'batch_size': 153, 'epoch': 571, 'train_rate': 0.8659869711270336, 'learning_rate': 0.0015094157149504377, 'weight_decay': 1.9701937140939235e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:36:56,797] Trial 31 finished with value: 0.3806583881378174 and parameters: {'batch_size': 126, 'epoch': 935, 'train_rate': 0.8999221268594564, 'learning_rate': 0.0003766563169368332, 'weight_decay': 0.00026770751062272813}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:38:12,773] Trial 32 finished with value: 0.41134509444236755 and parameters: {'batch_size': 112, 'epoch': 937, 'train_rate': 0.8836157412493694, 'learning_rate': 0.0003456664191720726, 'weight_decay': 0.00029233887668870135}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:38:56,360] Trial 33 finished with value: 0.4113476773103078 and parameters: {'batch_size': 46, 'epoch': 859, 'train_rate': 0.8862511783725142, 'learning_rate': 0.000661374295015069, 'weight_decay': 5.070217763178369e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:39:44,171] Trial 34 finished with value: 0.45355847477912903 and parameters: {'batch_size': 167, 'epoch': 796, 'train_rate': 0.8989764006605021, 'learning_rate': 0.0003386196022666194, 'weight_decay': 9.796036103746963e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:40:15,489] Trial 35 finished with value: 0.40901413559913635 and parameters: {'batch_size': 240, 'epoch': 696, 'train_rate': 0.8758615099617925, 'learning_rate': 0.0008503854808705821, 'weight_decay': 0.0004914534225317908}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:40:44,349] Trial 36 finished with value: 0.5201627016067505 and parameters: {'batch_size': 73, 'epoch': 589, 'train_rate': 0.8574304438155814, 'learning_rate': 0.005413809972174301, 'weight_decay': 0.00017356766749560308}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:41:27,105] Trial 37 finished with value: 0.41704973578453064 and parameters: {'batch_size': 203, 'epoch': 352, 'train_rate': 0.8860065576061453, 'learning_rate': 0.0012108717019790414, 'weight_decay': 8.082123653681047e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:42:03,113] Trial 38 finished with value: 0.5466236472129822 and parameters: {'batch_size': 155, 'epoch': 782, 'train_rate': 0.8698817095494245, 'learning_rate': 0.00024299685758433145, 'weight_decay': 0.007357318749097122}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:42:37,904] Trial 39 finished with value: 0.47661831974983215 and parameters: {'batch_size': 47, 'epoch': 901, 'train_rate': 0.8791501653593088, 'learning_rate': 0.0007841454885889162, 'weight_decay': 0.0006738182225522139}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:43:16,867] Trial 40 finished with value: 0.35689303278923035 and parameters: {'batch_size': 224, 'epoch': 122, 'train_rate': 0.8999199269951734, 'learning_rate': 0.0018335251676496087, 'weight_decay': 0.00036720773158021566}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:43:49,340] Trial 41 finished with value: 0.421885222196579 and parameters: {'batch_size': 225, 'epoch': 104, 'train_rate': 0.8997089217209518, 'learning_rate': 0.0022476490419098875, 'weight_decay': 0.000394321178177779}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:44:23,992] Trial 42 finished with value: 0.37663301825523376 and parameters: {'batch_size': 131, 'epoch': 191, 'train_rate': 0.8899102328655806, 'learning_rate': 0.0016061518357264454, 'weight_decay': 0.00023215664380944306}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:45:10,727] Trial 43 finished with value: 0.3770929276943207 and parameters: {'batch_size': 184, 'epoch': 178, 'train_rate': 0.8884877953226207, 'learning_rate': 0.0015359260551108724, 'weight_decay': 0.00018181948311708158}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:45:50,539] Trial 44 finished with value: 0.3723194897174835 and parameters: {'batch_size': 317, 'epoch': 160, 'train_rate': 0.8662281206688014, 'learning_rate': 0.0011655298974649663, 'weight_decay': 4.2469004306511314e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:46:37,091] Trial 45 finished with value: 0.41078832745552063 and parameters: {'batch_size': 343, 'epoch': 305, 'train_rate': 0.8617799049576405, 'learning_rate': 0.0011253134007767332, 'weight_decay': 4.049821814446078e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:46:59,608] Trial 46 finished with value: 0.46046870946884155 and parameters: {'batch_size': 314, 'epoch': 174, 'train_rate': 0.8762474024548353, 'learning_rate': 0.002344359380168217, 'weight_decay': 7.045131342200629e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:47:33,235] Trial 47 finished with value: 0.5141749382019043 and parameters: {'batch_size': 372, 'epoch': 410, 'train_rate': 0.8503137577105552, 'learning_rate': 0.0006759562533627939, 'weight_decay': 0.0001037047904411582}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:48:04,710] Trial 48 finished with value: 0.5297331213951111 and parameters: {'batch_size': 263, 'epoch': 142, 'train_rate': 0.8698881920069343, 'learning_rate': 0.008672422338869598, 'weight_decay': 2.0576691499330335e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 01:48:49,317] Trial 49 finished with value: 0.36250895261764526 and parameters: {'batch_size': 444, 'epoch': 235, 'train_rate': 0.8916618255562085, 'learning_rate': 0.0010389174081128323, 'weight_decay': 4.4213522786517986e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# ...
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:12:22,291] Trial 83 finished with value: 0.400086373090744 and parameters: {'batch_size': 182, 'epoch': 689, 'train_rate': 0.8886101886604933, 'learning_rate': 0.0007751895724748686, 'weight_decay': 9.015589501214012e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:13:17,969] Trial 84 finished with value: 0.39724278450012207 and parameters: {'batch_size': 65, 'epoch': 885, 'train_rate': 0.8946354447195471, 'learning_rate': 0.0010397080998706045, 'weight_decay': 3.46343264311718e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:13:51,984] Trial 85 finished with value: 0.4302949607372284 and parameters: {'batch_size': 117, 'epoch': 653, 'train_rate': 0.8846388752355545, 'learning_rate': 0.001488398509399175, 'weight_decay': 4.5249075294719536e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:14:29,285] Trial 86 finished with value: 0.4287796914577484 and parameters: {'batch_size': 278, 'epoch': 598, 'train_rate': 0.8776519285224568, 'learning_rate': 0.0006763299683893538, 'weight_decay': 6.612961798880504e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:14:47,726] Trial 87 finished with value: 0.5150427222251892 and parameters: {'batch_size': 210, 'epoch': 718, 'train_rate': 0.8993748600345816, 'learning_rate': 0.0016712427219796753, 'weight_decay': 9.63730696730927e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:15:17,496] Trial 88 finished with value: 0.42533010244369507 and parameters: {'batch_size': 247, 'epoch': 209, 'train_rate': 0.8900838995976609, 'learning_rate': 0.0019939691407262696, 'weight_decay': 2.668156758546395e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:15:46,199] Trial 89 finished with value: 0.4836515486240387 and parameters: {'batch_size': 228, 'epoch': 870, 'train_rate': 0.8695491299882232, 'learning_rate': 0.0009702983157262628, 'weight_decay': 0.0001287069159182634}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:16:31,054] Trial 90 finished with value: 0.5151549577713013 and parameters: {'batch_size': 101, 'epoch': 816, 'train_rate': 0.8954490269212212, 'learning_rate': 0.00039086283101669227, 'weight_decay': 0.00017414134633863507}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:17:14,355] Trial 91 finished with value: 0.4774828255176544 and parameters: {'batch_size': 153, 'epoch': 805, 'train_rate': 0.879956238288134, 'learning_rate': 0.0008075459857969855, 'weight_decay': 2.1749763527180762e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:17:40,141] Trial 92 finished with value: 0.4043373465538025 and parameters: {'batch_size': 128, 'epoch': 741, 'train_rate': 0.8842052781868963, 'learning_rate': 0.0007485556402948219, 'weight_decay': 3.533080660008998e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:18:42,311] Trial 93 finished with value: 0.4343007504940033 and parameters: {'batch_size': 146, 'epoch': 824, 'train_rate': 0.8779420021671323, 'learning_rate': 0.0013060210915766123, 'weight_decay': 1.7846860365396628e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:19:40,537] Trial 94 finished with value: 0.3919087052345276 and parameters: {'batch_size': 173, 'epoch': 771, 'train_rate': 0.8903708964910826, 'learning_rate': 0.0005069939474761958, 'weight_decay': 2.2081651885932486e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:20:26,220] Trial 95 finished with value: 0.3979472219944 and parameters: {'batch_size': 191, 'epoch': 912, 'train_rate': 0.8945019568730581, 'learning_rate': 0.0006278628473054508, 'weight_decay': 4.537597789911863e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:21:00,930] Trial 96 finished with value: 0.39592859148979187 and parameters: {'batch_size': 161, 'epoch': 123, 'train_rate': 0.8999393916384748, 'learning_rate': 0.0010999478794274764, 'weight_decay': 1.2415498396961184e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:21:46,052] Trial 97 finished with value: 0.3976542353630066 and parameters: {'batch_size': 512, 'epoch': 243, 'train_rate': 0.8842294914189402, 'learning_rate': 0.0008540307965270908, 'weight_decay': 1.8140827531321106e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:22:19,167] Trial 98 finished with value: 0.45743507146835327 and parameters: {'batch_size': 175, 'epoch': 794, 'train_rate': 0.8890795027566997, 'learning_rate': 0.0024732247651519652, 'weight_decay': 3.191905988029185e-05}. Best is trial 14 with value: 0.3106837868690491.
# <ipython-input-12-2ee3ca384a26>:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-2)
# <ipython-input-12-2ee3ca384a26>:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-2)
# [I 2023-04-19 02:22:52,211] Trial 99 finished with value: 0.48175469040870667 and parameters: {'batch_size': 138, 'epoch': 842, 'train_rate': 0.877206812942953, 'learning_rate': 0.00146758180992548, 'weight_decay': 7.160186420710724e-05}. Best is trial 14 with value: 0.3106837868690491.
# Best trial:
#   Value: 0.3106837868690491
#   Params:
#     batch_size: 149
#     epoch: 897
#     train_rate: 0.8966428653293104
#     learning_rate: 0.0005452702173718947
#     weight_decay: 0.00014473607817389365

# %%
def main():
  ligase_pocket = GraphData("ligase_pocket", root)
  target_pocket = GraphData("target_pocket", root)
  PROTAC = GraphData("PROTAC", root)
  with open('small_dataset/name.pkl','rb') as f:
      name_list = pickle.load(f)
  label = torch.load(os.path.join(target_pocket.processed_dir, "label.pt"))

  protac_set = PROTACSet(
      name_list,
      ligase_pocket, 
      target_pocket, 
      PROTAC, 
      label,
  )
  data_size = len(protac_set)
  train_size = int(data_size * TRAIN_RATE)
  test_size = data_size - train_size
  logging.info(f"all data: {data_size}")
  logging.info(f"train data: {train_size}")
  logging.info(f"test data: {test_size}")
  train_dataset = torch.utils.data.Subset(protac_set, range(train_size))
  test_dataset = torch.utils.data.Subset(protac_set, range(train_size, data_size))
  trainloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collater, drop_last=False)
  testloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collater,drop_last=False)
    
  ligase_pocket_model = GraphConv(num_embeddings=5)
  target_pocket_model = GraphConv(num_embeddings=5)
  PROTAC_model = GraphConv(num_embeddings=10)
  model = ProtacModel(
      ligase_pocket_model,
      target_pocket_model,
      PROTAC_model,
  )
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  writer = SummaryWriter(f'runs/{TRAIN_NAME}')
  model, train_loss, val_loss = train(
      model, 
      train_loader=trainloader, 
      valid_loader=testloader,
      device=device,
      writer=writer,
      LOSS_NAME=TRAIN_NAME,
      batch_size=BATCH_SIZE,
      epoch=EPOCH,
      lr=LEARNING_RATE,
      weight_decay = WEIGHT_DECAY
  )

  for handler in logging.root.handlers[:]:
      logging.root.removeHandler(handler)
  return train_loss, val_loss

# %%
def main_large():
  root = "large_dataset/data"
  with open('large_dataset/name.pkl','rb') as f:
        name_list = pickle.load(f)
  data_size = len(name_list)/2
  train_size = int(data_size * TRAIN_RATE)
  test_size = data_size - train_size

  train_ligase_pocket = GraphData("ligase_pocket", root)[:train_size] + GraphData("ligase_pocket", root)[949:949+train_size]
  test_ligase_pocket = GraphData("ligase_pocket", root)[train_size:949] + GraphData("ligase_pocket", root)[949+train_size:]
  train_target_pocket = GraphData("target_pocket", root)[:train_size] + GraphData("target_pocket", root)[949:949+train_size]
  test_target_pocket = GraphData("target_pocket", root)[train_size:949] + GraphData("target_pocket", root)[949+train_size:]
  train_PROTAC= GraphData("PROTAC", root)[:train_size] + GraphData("PROTAC", root)[949:949+train_size]
  test_PROTAC = GraphData("PROTAC", root)[train_size:949] + GraphData("PROTAC", root)[949+train_size:]

  with open('large_dataset/name.pkl','rb') as f:
        name_list = pickle.load(f)
  train_name = name_list[:train_size] + name_list[949:949+train_size]
  test_name = name_list[train_size:949] + name_list[949+train_size:]

  label = torch.load(root+"/processed/label.pt")
  train_label = label[:train_size] + label[949:949+train_size]
  test_label = label[train_size:949] + label[949+train_size:]

  train_set = PROTACSet(
    train_name,
    train_ligase_pocket, 
    train_target_pocket, 
    train_PROTAC, 
    train_label,
  )

  valid_set = PROTACSet(
    test_name,
    test_ligase_pocket, 
    test_target_pocket, 
    test_PROTAC, 
    test_label,
  )

  data_size = len(train_set) + len(valid_set)
  train_size = len(train_set)
  test_size = len(valid_set)
  logging.info(f"all data: {data_size}")
  logging.info(f"train data: {train_size}")
  logging.info(f"test data: {test_size}")
  trainloader = DataLoader(train_set, batch_size=BATCH_SIZE, collate_fn=collater,drop_last=False, shuffle=True)
  testloader = DataLoader(valid_set, batch_size=BATCH_SIZE, collate_fn=collater,drop_last=False, shuffle=True)


  ligase_pocket_model = GraphConv(num_embeddings=5)
  target_pocket_model = GraphConv(num_embeddings=5)
  PROTAC_model = GraphConv(num_embeddings=10)

  model = ProtacModel( 
      ligase_pocket_model,
      target_pocket_model,
      PROTAC_model,
  )
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  writer = SummaryWriter(f'runs/{TRAIN_NAME}')
  model, train_loss, val_loss = train(
      model, 
      train_loader=trainloader, 
      valid_loader=testloader,
      device=device,
      writer=writer,
      LOSS_NAME=TRAIN_NAME,
      batch_size=BATCH_SIZE,
      epoch=EPOCH,
      lr=LEARNING_RATE,
      weight_decay = WEIGHT_DECAY
  )
  for handler in logging.root.handlers[:]:
      logging.root.removeHandler(handler)
  return train_loss, val_loss

# %%
train_loss, val_loss = main_large()
# Out:
# Processing...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-eafb58ae831a> in <cell line: 1>()
# ----> 1 train_loss, val_loss = main_large()
#
# <ipython-input-10-fda4ef5c2b19> in main_large()
#       7   test_size = data_size - train_size
#       8
# ----> 9   train_ligase_pocket = GraphData("ligase_pocket", root)[:train_size] + GraphData("ligase_pocket", root)[949:949+train_size]
#      10   test_ligase_pocket = GraphData("ligase_pocket", root)[train_size:949] + GraphData("ligase_pocket", root)[949+train_size:]
#      11   train_target_pocket = GraphData("target_pocket", root)[:train_size] + GraphData("target_pocket", root)[949:949+train_size]
#
# /content/drive/.shortcut-targets-by-id/1_2em3v0TLxpcrRipRJlWxC6PKaqk5biD/DeepPROTACs/prepare_data2.py in __init__(self, name, root)
#      58 class GraphData(InMemoryDataset):
#      59     def __init__(self, name, root="data"):
# ---> 60         super().__init__(root)
#      61         if name == "ligase_ligand":
#      62             self.data, self.slices = torch.load(self.processed_paths[0])
#
# /usr/local/lib/python3.9/dist-packages/torch_geometric/data/in_memory_dataset.py in __init__(self, root, transform, pre_transform, pre_filter, log)
#      55         log: bool = True,
#      56     ):
# ---> 57         super().__init__(root, transform, pre_transform, pre_filter, log)
#      58         self._data = None
#      59         self.slices = None
#
# /usr/local/lib/python3.9/dist-packages/torch_geometric/data/dataset.py in __init__(self, root, transform, pre_transform, pre_filter, log)
#      95
#      96         if self.has_process:
# ---> 97             self._process()
#      98
#      99     def indices(self) -> Sequence:
#
# /usr/local/lib/python3.9/dist-packages/torch_geometric/data/dataset.py in _process(self)
#     228
#     229         makedirs(self.processed_dir)
# --> 230         self.process()
#     231
#     232         path = osp.join(self.processed_dir, 'pre_transform.pt')
#
# /content/drive/.shortcut-targets-by-id/1_2em3v0TLxpcrRipRJlWxC6PKaqk5biD/DeepPROTACs/prepare_data2.py in process(self)
#      81
#      82     def process(self):
# ---> 83         with open('name.pkl','rb') as f:
#      84             name_list = pickle.load(f)
#      85
#
# FileNotFoundError: [Errno 2] No such file or directory: 'name.pkl'

# %%
for handler in logging.root.handlers[:]:
      logging.root.removeHandler(handler)

# %% [markdown]
# ```
# # This is formatted as code
#   label_train = []
#   for data_sample in train_dataset:
#         label_train.append(data_sample["label"])
#   lu_train, count_train = np.unique(label_train,return_counts=True)
#   cw_train = [sum(count_train) / c for c in count_train]
#   ew_train = [cw_train[e] for e in label_train]
#   sampler_train = WeightedRandomSampler(weights=ew_train, num_samples = int(2*len(label_train)), replacement=True)
#
#   label_test = []
#   for data_sample in test_dataset:
#         label_test.append(data_sample["label"])
#   lu_test, count_test = np.unique(label_test,return_counts=True)
#   cw_test = [sum(count_test) / c for c in count_test]
#   ew_test = [cw_test[e] for e in label_test]
#   sampler_test = WeightedRandomSampler(weights=ew_test, num_samples = int(2*len(label_test)), replacement=True)
# ```
